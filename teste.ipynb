# %%
import pandas as pd

# %%
# Sample DataFrame
pd.set_option('display.float_format', '{:.0f}'.format)
df = pd.read_csv('/home/uiot/Área de Trabalho/teste/fake_position.csv')

# %%
# Group by 'category' and sum up 'value'

df.groupby(['account_code', 'account_suitability','class_name'])['position_value'].sum().reset_index().rename(columns={'position_value' : 'Soma'})
# Out:
#      account_code account_suitability             class_name      Soma
# 0            2429            moderado    Renda Fixa Inflação 134310122
# 1            2429            moderado  Renda Fixa Pré-Fixada    296873
# 2            2429            moderado  Renda Fixa Pós-Fixada      6426
# 3            2429            moderado    Reserva de Liquidez     13062
# 4            2429            moderado         Saldo em Conta         0
# ..            ...                 ...                    ...       ...
# 149         82356         conservador    Renda Fixa Inflação     27429
# 150         82356         conservador  Renda Fixa Pré-Fixada     31445
# 151         82356         conservador  Renda Fixa Pós-Fixada     37428
# 152         82356         conservador    Reserva de Liquidez    290475
# 153         82356         conservador         Saldo em Conta         0
#
# [154 rows x 4 columns]
